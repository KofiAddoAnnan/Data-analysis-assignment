# %% [markdown]
# # FIFA DATASET ANALYSIS

# %% [markdown]
# Make sure to import your necessary libraries , read your fifa data downloaded
#
# and try gaining some insights from the data (with the basic functions we learnt) before answering the questions below

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fifa = pd.read_excel(r'C:\Users\user\Desktop\Desktop\Python for Everyone Codes\Data Analysis Assignment\Fifa-drive-download-20230630T102024Z-001\fifa_data-2.xlsx')

# %%
fifa.head()
# Out:
#    Column1      ID               Name  Age  \
# 0  Column1      ID               Name  Age
# 1        0  158023           L. Messi   31
# 2        1   20801  Cristiano Ronaldo   33
# 3        2  190871          Neymar Jr   26
# 4        3  193080             De Gea   27
#
#                                             Photo  Nationality  \
# 0                                           Photo  Nationality
# 1  https://cdn.sofifa.org/players/4/19/158023.png    Argentina
# 2   https://cdn.sofifa.org/players/4/19/20801.png     Portugal
# 3  https://cdn.sofifa.org/players/4/19/190871.png       Brazil
# 4  https://cdn.sofifa.org/players/4/19/193080.png        Spain
#
#                                   Flag  Overall  Potential  \
# 0                                 Flag  Overall  Potential
# 1  https://cdn.sofifa.org/flags/52.png       94         94
# 2  https://cdn.sofifa.org/flags/38.png       94         94
# 3  https://cdn.sofifa.org/flags/54.png       92         93
# ...

# %%
fifa.tail()
# Out:
#       Column1      ID                Name Age  \
# 18202   18202  238813        J. Lundstram  19
# 18203   18203  243165  N. Christoffersson  19
# 18204   18204  241638           B. Worman  16
# 18205   18205  246268      D. Walker-Rice  17
# 18206   18206  246269           G. Nugent  16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag Overall Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png      47        65
# 18203  https://cdn.sofifa.org/flags/46.png      47        63
# 18204  https://cdn.sofifa.org/flags/14.png      47        67
# ...

# %%
fifa.columns
# Out:
# Index(['Column1', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Release Clause'],
#       dtype='object')

# %%
fifa.dtypes
# Out:
# Column1           object
# ID                object
# Name              object
# Age               object
# Photo             object
#                    ...
# GKHandling        object
# GKKicking         object
# GKPositioning     object
# GKReflexes        object
# Release Clause    object
# Length: 62, dtype: object

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 62 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Column1                   18207 non-null  object
#  1   ID                        18207 non-null  object
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  object
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  object
#  8   Potential                 18207 non-null  object
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Wage                      17966 non-null  object
#  12  Special                   18207 non-null  object
# ...

# %%
fifa.describe()
# Out:
#         Column1     ID          Name    Age  Photo Nationality  \
# count     18207  18207         18207  18207  18207       18207
# unique    18207  18207         17194     30  18207         165
# top     Column1     ID  J. Rodríguez     21  Photo     England
# freq          1      1            11   1423      1        1662
#
#                                        Flag  Overall  Potential  \
# count                                 18207    18207      18207
# unique                                  165       49         48
# top     https://cdn.sofifa.org/flags/14.png       66         70
# freq                                   1662     1163       1203
#
#                     Club  ... Composure Marking  StandingTackle SlidingTackle  \
# count              17966  ...     18159   18159           18159         18159
# unique               652  ...        85      93              91            89
# top     Newcastle United  ...        60      60              66            62
# ...

# %%
fifa.isnull().sum()
# Out:
# Column1              0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 62, dtype: int64

# %%
fifa_1 = fifa.copy()

# %%
fifa_1.head()
# Out:
#    Column1      ID               Name  Age  \
# 0  Column1      ID               Name  Age
# 1        0  158023           L. Messi   31
# 2        1   20801  Cristiano Ronaldo   33
# 3        2  190871          Neymar Jr   26
# 4        3  193080             De Gea   27
#
#                                             Photo  Nationality  \
# 0                                           Photo  Nationality
# 1  https://cdn.sofifa.org/players/4/19/158023.png    Argentina
# 2   https://cdn.sofifa.org/players/4/19/20801.png     Portugal
# 3  https://cdn.sofifa.org/players/4/19/190871.png       Brazil
# 4  https://cdn.sofifa.org/players/4/19/193080.png        Spain
#
#                                   Flag  Overall  Potential  \
# 0                                 Flag  Overall  Potential
# 1  https://cdn.sofifa.org/flags/52.png       94         94
# 2  https://cdn.sofifa.org/flags/38.png       94         94
# 3  https://cdn.sofifa.org/flags/54.png       92         93
# ...

# %%
fifa_1.drop(0, inplace = True)

# %%
fifa_1.head()
# Out:
#   Column1      ID               Name Age  \
# 1       0  158023           L. Messi  31
# 2       1   20801  Cristiano Ronaldo  33
# 3       2  190871          Neymar Jr  26
# 4       3  193080             De Gea  27
# 5       4  192985       K. De Bruyne  27
#
#                                             Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 2   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 3  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 4  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 5  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag Overall Potential                 Club  \
# 1  https://cdn.sofifa.org/flags/52.png      94        94         FC Barcelona
# 2  https://cdn.sofifa.org/flags/38.png      94        94             Juventus
# 3  https://cdn.sofifa.org/flags/54.png      92        93  Paris Saint-Germain
# ...

# %%
fifa_1.set_index('Column1', inplace = True)

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1.shape
# Out:
# (18206, 61)

# %% [markdown]
# # Q1. Who is the oldest player?

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1.describe()
# Out:
#             ID          Name    Age  \
# count    18206         18206  18206
# unique   18206         17193     29
# top     158023  J. Rodríguez     21
# freq         1            11   1423
#
#                                                  Photo Nationality  \
# count                                            18206       18206
# unique                                           18206         164
# top     https://cdn.sofifa.org/players/4/19/158023.png     England
# freq                                                 1        1662
#
#                                        Flag  Overall  Potential          Club  \
# count                                 18206    18206      18206         17965
# unique                                  164       48         47           651
# top     https://cdn.sofifa.org/flags/14.png       66         70  FC Barcelona
# freq                                   1662     1163       1203            33
#
# ...

# %%
fifa_1['Age'].max()
# Out:
# 45

# %% [markdown]
# Now that I have an idea of the maximum age of the dataset, it is appropriate to use the .groupby() function to know the category associated to the maximum age. Category in this case is the 'Name' since the question wants WHO?

# %%
fifa_1.groupby('Name')['Age'].max().sort_values(ascending = False)
# Out:
# Name
# O. Pérez          45
# K. Pilkington     44
# T. Warner         44
# S. Narazaki       42
# B. Nivet          41
#                   ..
# Y. Roemer         16
# Pelayo Morilla    16
# B. Waine          16
# B. Worman         16
# M. Tilio          16
# Name: Age, Length: 17193, dtype: int64

# %% [markdown]
# The answer is 'O. Pérez' with age '45'

# %% [markdown]
# # Q2 Show a proportion or Right footed players against left footed players

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
fifa_1['Preferred Foot']
# Out:
# Column1
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18206, dtype: object

# %%
fifa_1['Weak Foot']
# Out:
# Column1
# 0        4
# 1        4
# 2        5
# 3        3
# 4        5
#         ..
# 18202    2
# 18203    2
# 18204    3
# 18205    3
# 18206    3
# Name: Weak Foot, Length: 18206, dtype: object

# %%
fifa_1['Preferred Foot'].value_counts()
# Out:
# Right    13947
# Left      4211
# Name: Preferred Foot, dtype: int64

# %% [markdown]
# The proportion of right footed players against left footed players is 13947 to 4211

# %%
fifa_1['Preferred Foot'].value_counts().plot( kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='Preferred Foot'>

# %% [markdown]
# # Q3.   Show the top 5 most represented countries in our fifa data.
#
# ### You could present on an appropriate chart / graph

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1['Nationality'].value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: Nationality, Length: 164, dtype: int64

# %% [markdown]
# Question demanded for top 5 most represented countries so I slice the data.

# %%
fifa_1['Nationality'].value_counts()[ : 5 : ]
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %% [markdown]
# Representing on a graph

# %%
fifa_1['Nationality'].value_counts()[ : 5 : ].plot(kind  = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Q4. Two boys are arguing that on average, right footed players have better finishing than left footed players.
#
# ## Can you prove who is right?

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1['Preferred Foot']
# Out:
# Column1
# 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18206, dtype: object

# %%
left_footed = fifa_1[fifa_1['Preferred Foot'] == 'Left']

# %%
left_footed.head()
# Out:
#              ID          Name Age  \
# Column1
# 0        158023      L. Messi  31
# 13       168542   David Silva  32
# 15       211110     P. Dybala  24
# 17       194765  A. Griezmann  27
# 19       192119   T. Courtois  26
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 13       https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 15       https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 17       https://cdn.sofifa.org/players/4/19/194765.png      France
# 19       https://cdn.sofifa.org/players/4/19/192119.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 13       https://cdn.sofifa.org/flags/45.png      90        90
# 15       https://cdn.sofifa.org/flags/52.png      89        94
# ...

# %%
len(left_footed)
# Out:
# 4211

# %%
right_footed = fifa_1[fifa_1['Preferred Foot'] == 'Right']

# %%
right_footed.head()
# Out:
#              ID               Name Age  \
# Column1
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
# 5        183277          E. Hazard  27
#
#                                                   Photo Nationality  \
# Column1
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5        https://cdn.sofifa.org/players/4/19/183277.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# 3        https://cdn.sofifa.org/flags/45.png      91        93
# ...

# %%
len(right_footed)
# Out:
# 13947

# %%
left_footed['Finishing'].mean()
# Out:
# 47.0303965803847

# %%
right_footed['Finishing'].mean()
# Out:
# 45.10446691044669

# %% [markdown]
# With the above analysis, on average the left-footed have better finishing than the right-footed players

# %% [markdown]
# ## Q5. The Ghana black stars coach wants to call members for the national team.
#
# ####    He wants to prove to the nation that he is competent
#
# #### Can you help him with a list of players above average potential (that is above 50).

# %%
fifa_1.head()
# Out:
#              ID               Name Age  \
# Column1
# 0        158023           L. Messi  31
# 1         20801  Cristiano Ronaldo  33
# 2        190871          Neymar Jr  26
# 3        193080             De Gea  27
# 4        192985       K. De Bruyne  27
#
#                                                   Photo Nationality  \
# Column1
# 0        https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1         https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2        https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3        https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4        https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                         Flag Overall Potential  \
# Column1
# 0        https://cdn.sofifa.org/flags/52.png      94        94
# 1        https://cdn.sofifa.org/flags/38.png      94        94
# 2        https://cdn.sofifa.org/flags/54.png      92        93
# ...

# %%
fifa_1.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Wage', 'Special', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Real Face', 'Position', 'Jersey Number', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
blackstars = fifa_1[fifa_1['Nationality'] == 'Ghana']

# %%
blackstars.head()
# Out:
#              ID           Name Age  \
# Column1
# 249      209989      T. Partey  25
# 391      173909     K. Boateng  31
# 679      186832     K. Asamoah  29
# 1118     176571        A. Ayew  28
# 1226     213013  F. Acheampong  24
#
#                                                   Photo Nationality  \
# Column1
# 249      https://cdn.sofifa.org/players/4/19/209989.png       Ghana
# 391      https://cdn.sofifa.org/players/4/19/173909.png       Ghana
# 679      https://cdn.sofifa.org/players/4/19/186832.png       Ghana
# 1118     https://cdn.sofifa.org/players/4/19/176571.png       Ghana
# 1226     https://cdn.sofifa.org/players/4/19/213013.png       Ghana
#
#                                          Flag Overall Potential  \
# Column1
# 249      https://cdn.sofifa.org/flags/117.png      82        88
# 391      https://cdn.sofifa.org/flags/117.png      81        81
# 679      https://cdn.sofifa.org/flags/117.png      79        79
# ...

# %%
len(blackstars)
# Out:
# 114

# %%
blackstars['Potential'].value_counts()
# Out:
# 72    12
# 69    10
# 76    10
# 74     9
# 75     8
# 71     8
# 73     7
# 81     6
# 70     6
# 79     6
# 68     5
# 78     4
# 77     4
# 67     4
# 80     3
# 65     3
# 82     2
# 62     2
# 66     1
# 88     1
# 64     1
# 63     1
# 61     1
# Name: Potential, dtype: int64

# %%
blackstars['Potential'].min()
# Out:
# 61

# %% [markdown]
# The least potential of the Ghanaian players in the dataset is 61 which is already above the threshold of 50. Hence all the players are recommended.
